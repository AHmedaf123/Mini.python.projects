# %%
import random
print("KN BANAY GA COROR PATI\n")
name = input("Enter your name \n")
prize = 0
qa_list = [
    {"question": "Who is the founder of Pakistan?",
     "answer": "Quaid-e-Azam Muhammad Ali Jinnah",
     "options": ["Allama Iqbal", "Liaquat Ali Khan", "Quaid-e-Azam Muhammad Ali Jinnah", "Sir Syed Ahmed Khan"]},

    {"question": "When was Pakistan founded?",
     "answer": "14th August 1947",
     "options": ["15th August 1947", "14th August 1947", "23rd March 1940", "26th January 1950"]},

    {"question": "What is the national language of Pakistan?",
     "answer": "Urdu",
     "options": ["Punjabi", "Sindhi", "Urdu", "Pashto"]},

    {"question": "Which city is known as the 'City of Lights'?",
     "answer": "Karachi",
     "options": ["Lahore", "Islamabad", "Karachi", "Quetta"]},

    {"question": "What is the capital city of Pakistan?",
     "answer": "Islamabad",
     "options": ["Karachi", "Lahore", "Rawalpindi", "Islamabad"]},

    {"question": "What is the name of the highest mountain in Pakistan?",
     "answer": "K2 (Mount Godwin-Austen)",
     "options": ["Nanga Parbat", "K2 (Mount Godwin-Austen)", "Broad Peak", "Gasherbrum"]},

    {"question": "Which river is called the lifeline of Pakistan?",
     "answer": "River Indus",
     "options": ["River Jhelum", "River Ravi", "River Indus", "River Chenab"]},

    {"question": "What is the national sport of Pakistan?",
     "answer": "Field Hockey",
     "options": ["Cricket", "Football", "Field Hockey", "Squash"]},

    {"question": "Who wrote the national anthem of Pakistan?",
     "answer": "Hafeez Jalandhari",
     "options": ["Allama Iqbal", "Hafeez Jalandhari", "Josh Malihabadi", "Faiz Ahmed Faiz"]},

    {"question": "Which Pakistani scientist is known as the 'Father of the Atomic Bomb'?",
     "answer": "Dr. Abdul Qadeer Khan",
     "options": ["Dr. Abdul Salam", "Dr. Abdul Qadeer Khan", "Dr. Samar Mubarakmand", "Dr. Munir Ahmad Khan"]}
]
for question in qa_list:
  print(f"\nQuestion: {question['question']}")
  for i, option in enumerate(question['options']):
    print(f"{i+1}. {option}")
  try:
    user_choice = int(input("Enter your answer (1-4): "))
    if 1<=user_choice<=4:
      chosen_option = question['options'][user_choice-1]
      if chosen_option == question["answer"]:
        print("correct! 5000$ add to your prize.\n")
        prize += 5000
      else:
        print(f"wrong! the correct answer was: {question['answer']}\n")
    else:
      print("Invalid input! please enter a numeric option.\n")
  except ValueError:
    print("Invalid input! please enter a numeric option.\n")
print(f"you total prize is: ${prize}")
# Out:
# KN BANAY GA COROR PATI
#
# Enter your name
# Muhammad
#
# Question: Who is the founder of Pakistan?
# 1. Allama Iqbal
# 2. Liaquat Ali Khan
# 3. Quaid-e-Azam Muhammad Ali Jinnah
# 4. Sir Syed Ahmed Khan
# Enter your answer (1-4): 3
# correct! 5000$ add to your prize.
#
#
# Question: When was Pakistan founded?
# 1. 15th August 1947
# 2. 14th August 1947
# 3. 23rd March 1940
# 4. 26th January 1950
# Enter your answer (1-4): 2
# correct! 5000$ add to your prize.
#
#
# Question: What is the national language of Pakistan?
# 1. Punjabi
# 2. Sindhi
# 3. Urdu
# 4. Pashto
# Enter your answer (1-4): 3
# correct! 5000$ add to your prize.
#
#
# Question: Which city is known as the 'City of Lights'?
# 1. Lahore
# 2. Islamabad
# 3. Karachi
# 4. Quetta
# Enter your answer (1-4): 3
# correct! 5000$ add to your prize.
#
#
# Question: What is the capital city of Pakistan?
# 1. Karachi
# 2. Lahore
# 3. Rawalpindi
# 4. Islamabad
# Enter your answer (1-4): 4
# correct! 5000$ add to your prize.
#
#
# ...
